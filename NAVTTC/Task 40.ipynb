# %% [markdown]
# # Generate Random Number

# %%
from numpy import random

x = random.randint(100)

print(x)
# Out:
# 37

# %%
from numpy import random

x = random.rand()

print(x)
# Out:
# 0.89235919583665

# %%
from numpy import random

x = random.randint(100, size=(3, 5))

print(x)
# Out:
# [[53 21  0 85 68]
#  [23 69 69 99 73]
#  [24 58  0 28 82]]

# %% [markdown]
# # Generate Random Float

# %%
from numpy import random

x = random.rand()

print(x)
# Out:
# 0.23019561316532788

# %%
from numpy import random

x = random.rand(5)

print(x)
# Out:
# [0.14761118 0.92993555 0.99641792 0.80487253 0.58964013]

# %%
from numpy import random

x = random.rand(3, 5)

print(x)
# Out:
# [[0.27291344 0.9840068  0.04207724 0.85156385 0.58091098]
#  [0.90086288 0.80653806 0.41963105 0.47588382 0.71510588]
#  [0.45250754 0.82250149 0.38486322 0.43082163 0.75964842]]

# %% [markdown]
# # Generate Random Number From Array

# %%
from numpy import random

x = random.choice([3, 5, 7, 9])

print(x)
# Out:
# 5

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], size=(3, 5))

print(x)
# Out:
# [[9 7 7 9 3]
#  [9 5 5 7 7]
#  [3 5 3 3 3]]

# %% [markdown]
# ![image.png](attachment:c330b946-2aa1-48fa-933f-9f0ec3b04888.png)
