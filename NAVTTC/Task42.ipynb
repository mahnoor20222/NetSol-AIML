# %% [markdown]
# # Installation of Pandas

# %%
C:\Users\Your Name>pip install pandas

# %% [markdown]
# # Import Pandas

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# # Pandas as pd

# %%
import pandas as pd

# %% [markdown]
# # Checking Pandas Version

# %%
import pandas as pd

print(pd.__version__)

# %% [markdown]
# ![image.png](attachment:22bd3bce-c303-47a2-9603-7a3ebd990994.png)
