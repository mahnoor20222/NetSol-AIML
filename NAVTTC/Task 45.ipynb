# %% [markdown]
# # Pandas Read CSV

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df.to_string())

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df)

# %% [markdown]
# # max_rows

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# # Increase the maximum number of rows to display the entire DataFrame:

# %%
import pandas as pd

pd.options.display.max_rows = 9999

df = pd.read_csv('data.csv')

print(df)

# %% [markdown]
# ![image.png](attachment:ba383bcc-8ffa-4688-b5f9-06961daf59ab.png)
